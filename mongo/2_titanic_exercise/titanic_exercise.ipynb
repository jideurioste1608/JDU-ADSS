# %%
# Exercise 1 solution
# Your code here...

# %%
# Exercise 2 solution
# Your code here...

# %%
# Exercise 3 solution
# Your code here...

# %%
# Exercise 4 solution
# Your code here...

# %%
# Exercise 5 solution
# Your code here...

# %%
# Exercise 6 solution
# Your code here...

# %%
# Exercise 7 solution
# Your code here...
